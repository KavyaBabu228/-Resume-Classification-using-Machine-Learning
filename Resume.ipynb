# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import textract
import pandas as pd

# %%
folder_path = "/content/drive/MyDrive/Resumes_Docx"
print(os.listdir(folder_path))
# Out:
# ['workday', 'SQL Developer', 'React Developer', 'Peoplesoft Resume', 'Peoplesoft']

# %%
file_path1 = []
category1 = []

directory1 = '/content/drive/MyDrive/Resumes_Docx/workday'

# Check if the directory exists before proceeding
if os.path.exists(directory1):
    for i in os.listdir(directory1):
        if i.endswith('.docx'):
            file_path = os.path.join(directory1, i)
            try:
                text = textract.process(file_path).decode('utf-8')
                file_path1.append(text)
                category1.append('workday')
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
else:
    print(f"Directory '{directory1}' not found. Please check the path.")

# Create a DataFrame
data1 = pd.DataFrame({'Raw_Details': file_path1, 'Category1': category1})

# Display the DataFrame
print(data1)
# Out:
#                                           Raw_Details Category1
# 0   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...   workday
# 1   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...   workday
# 2   Workday HCM  Techno functional Consultant     ...   workday
# 3   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...   workday
# 4   G Himaja\n\n                                  ...   workday
# 5   Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...   workday
# 6   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...   workday
# 7   Srikanth (WORKDAY hCM Consultant)\t           ...   workday
# 8   Mooraboyina Guravaiah\n\nWorkday Integration S...   workday
# 9   Vinay kumar .v\nWorkday Functional Consultant\...   workday
# 10  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...   workday

# %%
file_path2 = []
category2 = []

directory2 = '/content/drive/MyDrive/Resumes_Docx/SQL Developer'

# Check if the directory exists before proceeding
if os.path.exists(directory2):
    for i in os.listdir(directory2):
        if i.endswith('.docx'):
            file_path = os.path.join(directory2, i)
            try:
                text = textract.process(file_path).decode('utf-8')
                file_path2.append(text)
                category2.append('SQL Developer')
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
else:
    print(f"Directory '{directory2}' not found. Please check the path.")

# Create a DataFrame
data2 = pd.DataFrame({'Raw_Details': file_path2, 'Category2': category2})

# Display the DataFrame
print(data2)
# Out:
#                                           Raw_Details      Category2
# 0   Aradhana Tripathi\n\n\n\nCurrent Location: Gac...  SQL Developer
# 1   SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...  SQL Developer
# 2   Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...  SQL Developer
# 3   resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...  SQL Developer
# 4   SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...  SQL Developer
# 5   Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...  SQL Developer
# 6   BUDDHA VAMSI                                  ...  SQL Developer
# 7   KAMBALLA PRADEEP                              ...  SQL Developer
# 8   RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...  SQL Developer
# 9   SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...  SQL Developer
# 10  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...  SQL Developer

# %%
file_path3 = []
category3 = []

directory3 = '/content/drive/MyDrive/Resumes_Docx/React Developer'

# Check if the directory exists before proceeding
if os.path.exists(directory3):
    for i in os.listdir(directory3):
        if i.endswith('.docx'):
            file_path = os.path.join(directory3, i)
            try:
                text = textract.process(file_path).decode('utf-8')
                file_path3.append(text)
                category3.append('React Developer')
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
else:
    print(f"Directory '{directory3}' not found. Please check the path.")

# Create a DataFrame
data3 = pd.DataFrame({'Raw_Details': file_path3, 'Category3': category3})

# Display the DataFrame
print(data3)
# Out:
#                                           Raw_Details        Category3
# 0   SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...  React Developer
# 1   KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...  React Developer
# 2   Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...  React Developer
# 3   Ui-Developer/ React JS Developer \n\nNAME: KRI...  React Developer
# 4   MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...  React Developer
# 5   Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...  React Developer
# 6   Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...  React Developer
# 7   Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...  React Developer
# 8   Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...  React Developer
# 9   MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...  React Developer
# 10  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...  React Developer
# 11  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...  React Developer
# ...

# %%
file_path4 = []
category4 = []

directory4 = '/content/drive/MyDrive/Resumes_Docx/Peoplesoft Resume'

# Check if the directory exists before proceeding
if os.path.exists(directory4):
    for i in os.listdir(directory4):
        if i.endswith('.docx'):
            file_path = os.path.join(directory4, i)
            try:
                text = textract.process(file_path).decode('utf-8')
                file_path4.append(text)
                category4.append('Peoplesoft Resume')
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
else:
    print(f"Directory '{directory4}' not found. Please check the path.")

# Create a DataFrame
data4 = pd.DataFrame({'Raw_Details': file_path4, 'Category4': category4})

# Display the DataFrame
print(data4)
# Out:
#                                          Raw_Details          Category4
# 0  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  Peoplesoft Resume
# 1  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  Peoplesoft Resume
# 2  Classification: Internal\n\nClassification: In...  Peoplesoft Resume
# 3  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  Peoplesoft Resume
# 4  PeopleSoft Administration\n\n \n\nVivekanand S...  Peoplesoft Resume
# 5  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  Peoplesoft Resume
# 6  Hari Narayana \t\t              \n\n\t\n\n\n\n...  Peoplesoft Resume
# 7  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  Peoplesoft Resume
# 8  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  Peoplesoft Resume
# 9  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  Peoplesoft Resume

# %%
file_path5 = []
category5 = []

directory5 = '/content/drive/MyDrive/Resumes_Docx/Peoplesoft'

# Check if the directory exists before proceeding
if os.path.exists(directory5):
    for i in os.listdir(directory5):
        if i.endswith('.docx'):
            file_path = os.path.join(directory5, i)
            try:
                text = textract.process(file_path).decode('utf-8')
                file_path5.append(text)
                category5.append('Peoplesoft')
            except Exception as e:
                print(f"Error processing {file_path}: {e}")
else:
    print(f"Directory '{directory5}' not found. Please check the path.")

# Create a DataFrame
data5 = pd.DataFrame({'Raw_Details': file_path5, 'Category5': category5})

# Display the DataFrame
print(data5)
# Out:
# Error processing /content/drive/MyDrive/Resumes_Docx/Peoplesoft/Peoplesoft Admin_G Ananda Rayudu.docx: "There is no item named 'word/document.xml' in the archive"
# Empty DataFrame
# Columns: [Raw_Details, Category5]
# Index: []

# %%
resume_data = pd.concat([data1, data2, data3, data4, data5], ignore_index=True)
resume_data
# Out:
#                                           Raw_Details Category1  \
# 0   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...   workday
# 1   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...   workday
# 2   Workday HCM  Techno functional Consultant     ...   workday
# 3   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...   workday
# 4   G Himaja\n\n                                  ...   workday
# 5   Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...   workday
# 6   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...   workday
# 7   Srikanth (WORKDAY hCM Consultant)\t           ...   workday
# 8   Mooraboyina Guravaiah\n\nWorkday Integration S...   workday
# 9   Vinay kumar .v\nWorkday Functional Consultant\...   workday
# 10  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...   workday
# 11  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...       NaN
# 12  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...       NaN
# 13  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...       NaN
# ...

# %%
resume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raw_Details  52 non-null     object
#  1   Category1    11 non-null     object
#  2   Category2    11 non-null     object
#  3   Category3    20 non-null     object
#  4   Category4    10 non-null     object
#  5   Category5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 2.6+ KB

# %%
resume_data['Category'] = category1 + category2 + category3 + category4 + category5
resume_data
# Out:
#                                           Raw_Details Category1  \
# 0   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...   workday
# 1   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...   workday
# 2   Workday HCM  Techno functional Consultant     ...   workday
# 3   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...   workday
# 4   G Himaja\n\n                                  ...   workday
# 5   Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...   workday
# 6   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...   workday
# 7   Srikanth (WORKDAY hCM Consultant)\t           ...   workday
# 8   Mooraboyina Guravaiah\n\nWorkday Integration S...   workday
# 9   Vinay kumar .v\nWorkday Functional Consultant\...   workday
# 10  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...   workday
# 11  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...       NaN
# 12  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...       NaN
# 13  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...       NaN
# ...

# %%
resume_data.drop(['Category1', 'Category2', 'Category3', 'Category4','Category5'], axis = 1, inplace = True)
resume_data = resume_data[["Category", "Raw_Details"]]

# %%
resume_data.head(15)
# Out:
#          Category                                        Raw_Details
# 0         workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1         workday  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 2         workday  Workday HCM  Techno functional Consultant     ...
# 3         workday  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 4         workday  G Himaja\n\n                                  ...
# 5         workday  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 6         workday  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 7         workday  Srikanth (WORKDAY hCM Consultant)\t           ...
# 8         workday  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 9         workday  Vinay kumar .v\nWorkday Functional Consultant\...
# 10        workday  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 11  SQL Developer  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 12  SQL Developer  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# ...

# %%
resume_data["Raw_Details"][4]
# Out:
# 'G Himaja\n\n                                                                                                            \n\n\n\n\n\nCareer Objective\n\n\n\nTo work towards achieving the greater success in my career through hard work, consistency and the ability to work with others to achieve organizational goals, aims and objectives.   \n\n    \n\nProfessional Summary\n\n\n\nHaving around 3 Years of IT ERP experience which include 2+ years as workday Integration Consultant and Remaining as HR.\n\n\n\n\tGood Involvement in Workday Projects full life cycle, Development / deployment, upgrades, Integrations etc.\n\n\n\n\tGood knowledge in the Functional Workday includes HCM, Compensation, Payroll interface, Business Process configurations, etc.\n\n\n\n\tExtensively worked on calculated fields used in developing various custom reports.\n\n\n\nStrong Knowledge on Involved in CR-Change Request as for business requirement and Building and moving changes to production.\n\n\n\n\tGood Exposure
# ...

# %%
resume_data.to_csv('Raw_Resume.csv', index=False)

# %%
resume_data = pd.read_csv("Raw_Resume.csv")
resume_data
# Out:
#              Category                                        Raw_Details
# 0             workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1             workday  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 2             workday  Workday HCM  Techno functional Consultant     ...
# 3             workday  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 4             workday  G Himaja\n\n                                  ...
# 5             workday  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 6             workday  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 7             workday  Srikanth (WORKDAY hCM Consultant)\t           ...
# 8             workday  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 9             workday  Vinay kumar .v\nWorkday Functional Consultant\...
# 10            workday  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 11      SQL Developer  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# ...

# %%
print(resume_data.columns)
# Out:
# Index(['Category', 'Raw_Details'], dtype='object')

# %%
resume_data[resume_data['Category'] == 'workday']
# Out:
#    Category                                        Raw_Details
# 0   workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1   workday  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 2   workday  Workday HCM  Techno functional Consultant     ...
# 3   workday  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 4   workday  G Himaja\n\n                                  ...
# 5   workday  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 6   workday  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 7   workday  Srikanth (WORKDAY hCM Consultant)\t           ...
# 8   workday  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 9   workday  Vinay kumar .v\nWorkday Functional Consultant\...
# 10  workday  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...

# %%
resume_data.isnull().sum()
# Out:
# Category       0
# Raw_Details    0
# dtype: int64

# %%
resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
resume_data[['Raw_Details','Word_Count']].head()
# Out:
#                                          Raw_Details  Word_Count
# 0  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         716
# 1  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...        1076
# 2  Workday HCM  Techno functional Consultant     ...        1334
# 3  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...         485
# 4  G Himaja\n\n                                  ...        1317

# %%
resume_data['Char_Count'] = resume_data['Raw_Details'].str.len() ## this also includes spaces
resume_data[['Raw_Details','Char_Count']].head()
# Out:
#                                          Raw_Details  Char_Count
# 0  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...        5951
# 1  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...        8329
# 2  Workday HCM  Techno functional Consultant     ...        9183
# 3  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...        4761
# 4  G Himaja\n\n                                  ...        5736
